# %%
import os
import shutil
import git
from fastapi import HTTPException
ex = "https://github.com/oDhruvPatel/constructionsite.git"
def git_repository_clone(repo_url: str) -> str:
    splitted = repo_url.split("/")
    repository_name = splitted[-1].replace(".git", "")
    return repository_name

git_repository_clone(ex)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 12
#       8     BASE_DIR = os.path.dirname(os.path.abspath(__file__))
#       9     repository_name = splitted[-1].replace(".git", "")
#      10     return BASE_DIR
#      11
# ---> 12 git_repository_clone(ex)
#
# Cell In[11], line 8, in git_repository_clone(repo_url)
#       6 def git_repository_clone(repo_url: str) -> str:
#       7     splitted = repo_url.split("/")
# ----> 8     BASE_DIR = os.path.dirname(os.path.abspath(__file__))
#       9     repository_name = splitted[-1].replace(".git", "")
#      10     return BASE_DIR
#
# NameError: name '__file__' is not defined
